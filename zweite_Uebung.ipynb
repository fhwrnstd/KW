# %% [markdown]
# <a href="https://colab.research.google.com/github/fhwrnstd/KW/blob/main/zweite_Uebung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from google.colab import drive
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt

# %%
url = 'https://info.gesundheitsministerium.gv.at/data/timeline-faelle-ems.csv'
df = pd.read_csv(url, sep=';')

# %%
df.head()
# Out:
#                        Datum  BundeslandID              Name  \
# 0  2021-03-01T08:00:00+01:00             1        Burgenland
# 1  2021-03-01T08:00:00+01:00             2           Kärnten
# 2  2021-03-01T08:00:00+01:00             3  Niederösterreich
# 3  2021-03-01T08:00:00+01:00             4    Oberösterreich
# 4  2021-03-01T08:00:00+01:00             5          Salzburg
#
#    BestaetigteFaelleEMS
# 0                 12375
# 1                 29226
# 2                 72922
# 3                 86410
# 4                 37902

# %%
df.describe()
# Out:
#        BundeslandID  BestaetigteFaelleEMS
# count   5600.000000          5.600000e+03
# mean       5.500000          4.213850e+05
# std        2.872538          8.125458e+05
# min        1.000000          1.237500e+04
# 25%        3.000000          6.639700e+04
# 50%        5.500000          1.443215e+05
# 75%        8.000000          4.315708e+05
# max       10.000000          5.010107e+06

# %%
df_filter = df.filter(['BestaetigteFaelleEMS'])
df_filter.plot()

# %%
df_filter = df.filter(['Datum','BundeslandID','Name'])
df_filter = df_filter.loc[(df_filter.Name=='Kärnten')]
df_filter.head()
# Out:
#                         Datum  BundeslandID     Name
# 1   2021-03-01T08:00:00+01:00             2  Kärnten
# 11  2021-03-02T08:00:00+01:00             2  Kärnten
# 21  2021-03-03T08:00:00+01:00             2  Kärnten
# 31  2021-03-04T08:00:00+01:00             2  Kärnten
# 41  2021-03-05T08:00:00+01:00             2  Kärnten

# %%
df_filter.plot()
